# %%
from pandas import read_csv as reader
import numpy as np

# %%
df = reader('naver.csv',encoding='utf-8').drop_duplicates(subset='Post ID')
df.to_csv('naver.csv',index=False)
# df['Images']
print(len(df))
df
# Out:
# 19351
#        Post ID                                          Post Link  \
# 0      2349018  https://cafe.naver.com/ArticleRead.nhn?clubid=...
# 1      2349015  https://cafe.naver.com/ArticleRead.nhn?clubid=...
# 2      2349014  https://cafe.naver.com/ArticleRead.nhn?clubid=...
# 3      2349013  https://cafe.naver.com/ArticleRead.nhn?clubid=...
# 4      2349011  https://cafe.naver.com/ArticleRead.nhn?clubid=...
# ...        ...                                                ...
# 19385  1875065  https://cafe.naver.com/ArticleRead.nhn?clubid=...
# 19386  1875057  https://cafe.naver.com/ArticleRead.nhn?clubid=...
# 19387  1875024  https://cafe.naver.com/ArticleRead.nhn?clubid=...
# 19388  1875011  https://cafe.naver.com/ArticleRead.nhn?clubid=...
# 19389  1874927  https://cafe.naver.com/ArticleRead.nhn?clubid=...
#
#                           Title   Author Author Level            Post Date  \
# 0                    '노20대존' 카페    정의에사도           점장  2023-08-10 15:15:00
# ...
